# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sn
import matplotlib.pyplot as plt

df = pd.read_csv('Pokemon.csv')

# %%
p = {'Grass':'#056608', 'Fire':'#f73718', 'Water':'#00008B', 'Bug':'#90EE90', 'Normal':'#F0EAD6',
    'Poison':'#b70df2', 'Electric':'#FFFF33', 'Ground':'#C4A484', 'Fairy':'#ffb6c1', 'Fighting': '#964B00', 'Psychic': '#3a243b',
    'Rock': '#5C4033', 'Ghost':'#452D2E', 'Ice':'#368BC1', 'Dragon': '#FFD580', 'Dark':'#070D0D', 'Steel': '#AAA9AD', 'Flying':'#87CEEB'}

# %%
sn.set_style(rc = {'axes.facecolor': '#000000', 'figure.facecolor':'#000000'})
sn.set(style='darkgrid')
sn.countplot(y=df["Type 1"], width = .5, palette=p)
# Out:
# <AxesSubplot: xlabel='count', ylabel='Type 1'>

# %%
sn.countplot(y=df["Type 2"], width = .5, palette=p)
# Out:
# <AxesSubplot: xlabel='count', ylabel='Type 2'>

# %%
plt.figure(figsize=(12,8))
notLegendary = df.query('Legendary == 0')
sn.swarmplot(x='Type 1', y= 'Total', data=notLegendary, color='#000000', size=3)
sn.violinplot(x='Type 1', y= 'Total', data=notLegendary, palette=p, inner=None)
# Out:
# <AxesSubplot: xlabel='Type 1', ylabel='Total'>

# %%
plt.figure(figsize=(12,8))
sn.swarmplot(x='Type 1', y= 'Total', data=df, color='#000000', size=3)
sn.violinplot(x='Type 1', y= 'Total', data=df, palette=p, inner=None)
# Out:
# <AxesSubplot: xlabel='Type 1', ylabel='Total'>
